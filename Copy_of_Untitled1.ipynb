# %% [markdown]
# <a href="https://colab.research.google.com/github/Ezra-A-Cohen/Webscraping/blob/main/Copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-98d079dc-602c-4c9f-ba83-6de7572be061" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98d079dc-602c-4c9f-ba83-6de7572be061">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving df (4).csv to df (4) (2).csv

# %%
import pandas as pd
import io
  
df = pd.read_csv(io.BytesIO(uploaded['df (4).csv']))
df = df.astype(str)
print(df)
# Out:
#             politician  ...            type
# 0            Joe Biden  ...       President
# 1       George W. Bush  ...       President
# 2         Barack Obama  ...       President
# 3         Donald Trump  ...       President
# 4    George H. W. Bush  ...       President
# ..                 ...  ...             ...
# 88  Daniel D. Tompkins  ...  Vice President
# 89          John Tyler  ...       President
# 90    Martin Van Buren  ...       President
# 91  William A. Wheeler  ...  Vice President
# 92        Henry Wilson  ...  Vice President
#
# [93 rows x 7 columns]

# %%
# !pip install wordcloud
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.19.5)

# %%
profs = []
for x in df.professions:
  profs.append(x)
print(profs)
#text = profs
#wordcloud = WordCloud().generate(text[:5])
wordcloud = WordCloud().generate(" ".join(profs))
#width = 1000, height = 500
# Out:
# ['lawyer - author - ', 'businessman - ', 'lawyer - author - ', 'businessman - television presenter - ', 'diplomat - businessman - ', 'Philanthropist - author - ', 'lawyer - professor - author - ', 'lawyer - ', 'Military officer - ', 'lawyer - ', 'journalist - ', 'engineer - ', 'teacher - ', 'journalist - ', 'lawyer - ', 'lawyer - author - ', 'trade unionist - actor - author - broadcaster - ', 'lawyer - ', 'Author - conservationist - explorer - historian - naturalist - police commissioner - soldier - sportsman - ', 'lawyer - ', 'farmer - ', 'academic - ', 'lawyer - ', 'lawyer - ', 'Lawyer - civil servant - ', 'lawyer - ', 'lawyer - ', 'lawyer - ', 'lawyer - amateur mathematician - ', 'Military officer - ', 'lawyer - ', 'Military officer - ', 'lawyer - ', 'lawyer - soldier - ', 'lawyer - ', 'tailor - ', 'lawyer - ', 'farmer - ', 'lawyer - ', 'lawyer - ', 'lawyer - ', 'lawyer - ', 'Military officer - ', 'lawyer - ', 'lawyer - ', 'lawyer - author - ', 'lawyer - ', 'environmentalist - lawyer - businessman - journalist - author - ', 'lawyer - author - ', 'lawyer - broadcaster - ', 'unknown', 'unknown', 'diplomat - businessman - ', 'lawyer - ', 'unknown', 'unknown', 'unknown', 'lawyer - ', 'unknown', 'environmentalist - lawyer - businessman - journalist - author - ', 'unknown', 'teacher - ', 'unknown', 'unknown', 'lawyer - author - ', 'unknown', 'unknown', 'Author - conservationist - explorer - historian - naturalist - police commissioner - soldier - sportsman - ', 'unknown', 'farmer - ', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'lawyer - ', 'unknown', 'unknown', 'unknown', 'attorney - ', 'lawyer - ', 'tailor - ', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'lawyer - ', 'lawyer - ', 'unknown', 'unknown']

# %%
repdf = df[df.party.eq("Republican")]
repwordcloud = repdf.professions
repdf
# Out:
#               politician  ...            type
# 1         George W. Bush  ...       President
# 3           Donald Trump  ...       President
# 4      George H. W. Bush  ...       President
# 7        Calvin Coolidge  ...       President
# 8   Dwight D. Eisenhower  ...       President
# 9            Gerald Ford  ...       President
# 10     Warren G. Harding  ...       President
# 11        Herbert Hoover  ...       President
# 14      William McKinley  ...       President
# 15         Richard Nixon  ...       President
# 16         Ronald Reagan  ...       President
# 18    Theodore Roosevelt  ...       President
# 19   William Howard Taft  ...       President
# 24     Chester A. Arthur  ...       President
# 28     James A. Garfield  ...       President
# 29      Ulysses S. Grant  ...       President
# 38      William McKinley  ...       President
# 46           Dick Cheney  ...  Vice President
# 49            Mike Pence  ...  Vice President
# 50           Spiro Agnew  ...  Vice President
# 52     George H. W. Bush  ...       President
# 53       Calvin Coolidge  ...       President
# 54        Charles Curtis  ...  Vice President
# 55      Charles G. Dawes  ...  Vice President
# 56  Charles W. Fairbanks  ...  Vice President
# 57           Gerald Ford  ...       President
# 64         Richard Nixon  ...       President
# 65            Dan Quayle  ...  Vice President
# 66    Nelson Rockefeller  ...  Vice President
# 67    Theodore Roosevelt  ...       President
# 68      James S. Sherman  ...  Vice President
# 70      Henry A. Wallace  ...  Vice President
# 81         Garret Hobart  ...  Vice President
# 86        Levi P. Morton  ...  Vice President
# 91    William A. Wheeler  ...  Vice President
#
# [35 rows x 7 columns]

# %%
demdf = df[df.party.eq("Democratic")]
demwordcloud = demdf.professions
demdf
# Out:
#                politician  ...            type
# 0               Joe Biden  ...       President
# 2            Barack Obama  ...       President
# 5            Jimmy Carter  ...       President
# 6            Bill Clinton  ...       President
# 12      Lyndon B. Johnson  ...       President
# 13        John F. Kennedy  ...       President
# 17  Franklin D. Roosevelt  ...       President
# 20        Harry S. Truman  ...       President
# 21         Woodrow Wilson  ...       President
# 26       Grover Cleveland  ...       President
# 35         Andrew Johnson  ...       President
# 40        Franklin Pierce  ...       President
# 41          James K. Polk  ...       President
# 45              Joe Biden  ...       President
# 47                Al Gore  ...  Vice President
# 48          Kamala Harris  ...  Vice President
# 51       Alben W. Barkley  ...  Vice President
# 58      John Nance Garner  ...  Vice President
# 59                Al Gore  ...  Vice President
# 61      Lyndon B. Johnson  ...       President
# 62        Thomas Marshall  ...  Vice President
# 63         Walter Mondale  ...  Vice President
# 69        Harry S. Truman  ...       President
# 71   John C. Breckinridge  ...  Vice President
# 76       George M. Dallas  ...  Vice President
# 79        Hannibal Hamlin  ...  Vice President
# 80    Thomas A. Hendricks  ...  Vice President
# 83         Andrew Johnson  ...       President
# 85        William R. King  ...  Vice President
# 87        Adlai Stevenson  ...  Vice President
#
# [30 rows x 7 columns]

# %%
rep_profs = []
for x in repdf.professions:
  rep_profs.append(x)
wordcloud = WordCloud(width = 1000, height = 500, background_color = "white").generate(" ".join(rep_profs))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from google.colab import files
#mask = files.upload()

# %%
import os
import matplotlib.pyplot as plt
os.system('curl -O https://static.wikia.nocookie.net/logopedia/images/8/88/Republican_%28GOP%29_logo.jpeg')
mask = plt.imread('Republican_%28GOP%29_logo.jpeg')
mask.shape[1]
#data
#elephant = np.array(mask)
# Out:
# 1024

# %%
wc = WordCloud(mask = mask, width = mask.shape[1], height = mask.shape[0], background_color = "white", contour_width = 2, contour_color = 'grey').generate(" ".join(rep_profs))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
wc.to_file("rep_cloud.png")
print(wc.words_.keys())
# Out:
# dict_keys(['lawyer', 'unknown', 'author', 'businessman', 'diplomat', 'Military', 'officer', 'broadcaster', 'conservationist', 'explorer', 'historian', 'naturalist', 'police', 'commissioner', 'soldier', 'sportsman', 'television', 'presenter', 'journalist', 'engineer', 'trade', 'unionist', 'actor', 'civil', 'servant', 'amateur', 'mathematician', 'attorney'])

# %%
dem_profs = []
for x in demdf.professions:
  dem_profs.append(x)
cloud = WordCloud(width = 1000, height = 500, background_color = "white").generate(" ".join(dem_profs))
plt.imshow(cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
os.system('curl -O https://i1.wp.com/www.cardinalandcream.info/wp-content/uploads/2019/10/CollegeDemocrats.jpg')
dem_mask = plt.imread('CollegeDemocrats.jpg')
print(mask)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
cloud = WordCloud(mask = dem_mask, width = mask.shape[1], height = mask.shape[0], background_color = "white", contour_width = 2, contour_color = 'grey').generate(" ".join(dem_profs))
plt.imshow(cloud, interpolation='bilinear')
plt.axis("off")
plt.show()
print(cloud.words_.keys())
# Out:
# dict_keys(['lawyer', 'unknown', 'author', 'journalist', 'teacher', 'farmer', 'tailor', 'environmentalist', 'businessman', 'Philanthropist', 'professor', 'academic'])

# %%
cloud.to_file("dem_cloud.png")
